# %%
from src.diffusion_map import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Part 1

# %%
data, time = gen_trigonom_data(1000)

# %%
nr_component = 3
lambda_pc, phi_pc, _ = diffusion_map(data, nr_component)
plot_part_one_eigenfunction(nr_component, time, phi_pc, lambda_pc)
