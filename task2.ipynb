# %%
from src.diffusion_map import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Part 1

# %%
data, time = gen_trigonom_data(1000)

# %%
nr_component = 3
lambda_pc, phi_pc, _ = diffusion_map(data, nr_component)
plot_eigenfunction(nr_component, time, phi_pc, lambda_pc)

# %% [markdown]
# # Part Two

# %%
X,t = gen_swiss_roll_data(5000, 0)
# Out:
# C:\Users\yinna\anaconda3\envs\MyML\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass noise=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=t, cmap=plt.cm.Spectral)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title("Swiss-Roll data manifold")
ax.view_init(0, 90)

# %%
nr_component = 3
lambda_pc, phi_pc, _ = diffusion_map(X, nr_component)
plot_eigenfunction(nr_component, t, phi_pc, lambda_pc)
